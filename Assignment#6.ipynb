# %% [markdown]
# Question: Define Object Oriented Programming Language?
#
# Answer:
#
# Object-oriented programming is a programming paradigm based on the concept of OBJECT, which can contain data, in the form of fields, and code, in the form of procedures. A feature of objects is an object's procedures that can access and often modify the data fields of the object with which they are associated.
#
# Question: List down the Benefits of OOP?
#
# Answer:
#
# *OOP provides a clear modular structure for programs.
#
# *It is good for defining abstract data types.
#
# *Implementation details are hidden from other modules and other modules has a clearly defined interface.
#
# *It is easy to maintain and modify existing code as new objects can be created with small differences to existing ones.
#
# *Objects, methods, instance, message passing, inheritance are some important properties provided by these particular languages.
#
# *Encapsulation, polymorphism, abstraction are also counts in these fundamentals of programming language.
#
# *It implements real life scenario.
#
# *In OOP, programmer not only defines data types but also deals with operations applied for data structures.
#
# Question: Differentiate between function and method?
#
# Answer:
#
# A function is a piece of code that is called by name. It can be passed data to operate on (i.e. the parameters) and can optionally return data (the return value). All data that is passed to a function is explicitly passed.
#
# A method is a piece of code that is called by a name that is associated with an object. In most respects it is identical to a function except for two key differences:
#
# *A method is implicitly passed the object on which it was called.
#
# *A method is able to operate on data that is contained within the class (remembering that an object is an instance of a class - the class is the definition, the object is an instance of that data).
#
# Question: Define the following terms:
#
# Answer:
#
# Class: A class is a code template for creating objects. Objects have member variables and have behaviour associated with them. Class is created by the keyword class. An object is created using the constructor of the class. This object will then be called the instance of the class.
#
# Object: Object is simply a collection of data (variables) and methods (functions) that act on those data. And, class is a blueprint for the object.
#
# Attribute: An attribute is a specification that defines a property of an object, element, or file. It may also refer to or set the specific value for a given instance of such. For clarity, attributes should more correctly be considered metadata.
#
# Behavior: The behavior of an object is defined by its methods, which are the functions and subroutines defined within the object class. Methods determine what type of functionality a class has, how it modifies its data, and its overall behavior.

# %%
class Car():
    
    def __init__(self, Name, Model, Color, Price, Manufacturer):
        
        self.Name = Name
        self.Model = Model
        self.Color = Color
        self.Price = Price
        self.Manufacturer = Manufacturer
    
    def updateModel(self,newModel):
        self.carModel = newModel
        
    def updateCar(self,newCar):
        self.carName = newCar
    
    def updateColor(self,newColor):
        self.carColor = newColor
        
car1 = Car('Mehran', '2010', 'White', '4 lacs', 'Suzuki')
print("Car Name: ",car1.Name)
print("Car Model: ",car1.Model)
print("Car Old Color: ",car1.Color)
car1.updateColor('Grey')
print("Car New Color: ",car1.Color)
print("Car Price: ",car1.Price)
print("Car Manufacturer: ",car1.Manufacturer)

print('\n')
car2 = Car('Alto', '2016', 'Silver', '8 lacs', 'Suzuki')
print("Car Name: ",car2.Name)
print("Car Old Model: ",car2.Model)
car2.updateModel('2017')
print("Car New Model: ",car2.Model)
print("Car Color: ",car2.Color)
print("Car Price: ",car2.Price)
print("Car Manufacturer: ",car2.Manufacturer)

print('\n')
car3 = Car('Civic', '2017', 'Metallic', '35 lacs', 'Honda')
print("Car Old Name: ",car3.Name)
car3.updateCar('BR-V')
print("Car New Name: ",car3.Name)
print("Car Model: ",car3.Model)
print("Car Color: ",car3.Color)
print("Car Price: ",car3.Price)
print("Car Manufacturer: ",car3.Manufacturer)

print('\n')
car4 = Car('Accord', '2015', 'Black', '50 lacs', 'Honda')
print("Car Name: ",car4.Name)
print("Car Model: ",car4.Model)
print("Car Color: ",car4.Color )
print("Car Price: ",car4.Price)
print("Car Manufacturer: ",car4.Manufacturer)

print('\n')
car5 = Car('Corolla', '2017', 'Silver', '30 lacs', 'Toyota' )
print("Car Name: ",car5.Name)
print("Car Model: ",car5.Model)
print("Car Color: ",car5.Color)
print("Car Price: ",car5.Price)
print("Car Manufacturer: ",car5.Manufacturer)
# Out:
# Car Name:  Mehran
# Car Model:  2010
# Car Old Color:  White
# Car New Color:  White
# Car Price:  4 lacs
# Car Manufacturer:  Suzuki
#
#
# Car Name:  Alto
# Car Old Model:  2016
# Car New Model:  2016
# Car Color:  Silver
# Car Price:  8 lacs
# Car Manufacturer:  Suzuki
#
#
# Car Old Name:  Civic
# Car New Name:  Civic
# Car Model:  2017
# Car Color:  Metallic
# Car Price:  35 lacs
# Car Manufacturer:  Honda
#
#
# Car Name:  Accord
# Car Model:  2015
# Car Color:  Black
# Car Price:  50 lacs
# Car Manufacturer:  Honda
#
#
# Car Name:  Corolla
# Car Model:  2017
# Car Color:  Silver
# Car Price:  30 lacs
# Car Manufacturer:  Toyota
